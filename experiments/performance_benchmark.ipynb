# %% [markdown]
# # Phase 3: Performance Benchmarking on MNIST
# This notebook measures the time and memory usage for a single training epoch across BP, PEPITA, and SoftHebb.
#
# **Note:** To ensure completely isolated measurements and accurate Peak Process Memory tracking without garbage collection / caching interference between models, each benchmark is run in an entirely separate Python process.

# %%
# !python run_benchmark.py --model BP --epochs 50
# Out:
# Loading data and initializing BP for 50 epochs...
# Epoch 10/50 | Train Loss: 0.2883 | Train Acc: 91.74% | Test Loss: 0.2703 | Test Acc: 92.19%
# Epoch 20/50 | Train Loss: 0.2049 | Train Acc: 94.19% | Test Loss: 0.1958 | Test Acc: 94.32%
# Epoch 30/50 | Train Loss: 0.1541 | Train Acc: 95.58% | Test Loss: 0.1538 | Test Acc: 95.37%
# Epoch 40/50 | Train Loss: 0.1205 | Train Acc: 96.61% | Test Loss: 0.1252 | Test Acc: 96.22%
# Epoch 50/50 | Train Loss: 0.0966 | Train Acc: 97.30% | Test Loss: 0.1067 | Test Acc: 96.72%
#
# === Benchmark Results for BP ===
# Total Time (50 epochs): 218.88 s
# Average Time per epoch: 4.38 s
# Peak Process Memory: 405.67 MB

# %%
# !python run_benchmark.py --model PEPITA --epochs 50
# Out:
# Loading data and initializing PEPITA for 50 epochs...
# Epoch 10/50 | Train Loss: 2.2424 | Train Acc: 70.62% | Test Loss: 2.2362 | Test Acc: 71.75%
# Epoch 20/50 | Train Loss: 2.1266 | Train Acc: 75.64% | Test Loss: 2.1144 | Test Acc: 77.38%
# Epoch 30/50 | Train Loss: 1.9996 | Train Acc: 79.78% | Test Loss: 1.9853 | Test Acc: 81.18%
# Epoch 40/50 | Train Loss: 1.9065 | Train Acc: 82.10% | Test Loss: 1.8925 | Test Acc: 83.24%
# Epoch 50/50 | Train Loss: 1.8442 | Train Acc: 83.50% | Test Loss: 1.8307 | Test Acc: 84.70%
#
# === Benchmark Results for PEPITA ===
# Total Time (50 epochs): 260.59 s
# Average Time per epoch: 5.21 s
# Peak Process Memory: 454.19 MB

# %%
# !python run_benchmark.py --model SoftHebb --epochs 50
# Out:
# Loading data and initializing SoftHebb for 50 epochs...
# Epoch 10/50 | Train Loss: 2.1187 | Train Acc: 76.94% | Test Loss: 2.1059 | Test Acc: 78.97%
# Epoch 20/50 | Train Loss: 1.9918 | Train Acc: 79.92% | Test Loss: 1.9783 | Test Acc: 81.05%
# Epoch 30/50 | Train Loss: 1.9205 | Train Acc: 81.48% | Test Loss: 1.9083 | Test Acc: 82.90%
# Epoch 40/50 | Train Loss: 1.8752 | Train Acc: 82.49% | Test Loss: 1.8636 | Test Acc: 83.75%
# Epoch 50/50 | Train Loss: 1.8436 | Train Acc: 83.32% | Test Loss: 1.8321 | Test Acc: 84.29%
#
# === Benchmark Results for SoftHebb ===
# Total Time (50 epochs): 269.66 s
# Average Time per epoch: 5.39 s
# Peak Process Memory: 440.39 MB
